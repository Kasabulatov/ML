# %% [markdown]
# <a href="https://colab.research.google.com/github/Kasabulatov/ML/blob/master/History_transactions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
# %MATPLOTLIB INLINE
# Out:
# UsageError: Line magic function `%MATPLOTLIB` not found.

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
# Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
link = 'https://drive.google.com/open?id=1jw76Adc-amYOLY1ala4QEOgR15JQm8IQ'

# %%
fluff, id = link.split('=')
print (id)
# Out:
# 1jw76Adc-amYOLY1ala4QEOgR15JQm8IQ

# %% [markdown]
# **<h1>Download the data**

# %%
downloaded = drive.CreateFile({'id':id}) 
downloaded.GetContentFile('hist1.csv')  
df = pd.read_csv('hist1.csv')

# %%
df.head()
# Out:
#          Data ObjectName  ... PloshadBalkonaPoTP ZhilayaPloshadPoTP
# 0  2019-01-26  Арнау - 8  ...                0.0                0.0
# 1  2019-01-26  Арнау - 8  ...                0.0                0.0
# 2  2019-01-26  Арнау - 8  ...                0.0                0.0
# 3  2019-01-26  Арнау - 8  ...                0.0                0.0
# 4  2019-01-26  Арнау - 8  ...                0.0                0.0
#
# [5 rows x 33 columns]

# %%
df['StoronySveta'].value_counts()
# Out:
# В     200305
# С     192263
# Ю     133910
# З     106542
# ЮЗ      4405
# ЮВ      1507
# СЗ       883
# СВ       330
# Name: StoronySveta, dtype: int64

# %%
df.shape
# Out:
# (2978443, 34)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Data', 'ObjectName', 'ObjectGUID', 'Pomeshcheniye',
#        'PomeshcheniyeGUID', 'DataVygruzki', 'Price', 'Etazh', 'Uglovaya',
#        'StoronySveta', 'Vidovaya', 'VidVoDvor', 'Cost', 'Area',
#        'PloshadVnutrenaya', 'RoomsCount', 'KolichestvoStoron', 'Podezd',
#        'Class', 'City', 'MaterialSten', 'Status', 'AgreementDate', 'SalePrice',
#        'Summa', 'ProcentVznosa', 'Aktsiya', 'AktsiyaGUID', 'DateOfSalesStart',
#        'FirstPrice', 'PloshadVnutrenayaPoTP', 'PloshadBalkonaPoTP',
#        'ZhilayaPloshadPoTP'],
#       dtype='object')

# %%
df.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
df.columns
# Out:
# Index(['Data', 'ObjectName', 'ObjectGUID', 'Pomeshcheniye',
#        'PomeshcheniyeGUID', 'DataVygruzki', 'Price', 'Etazh', 'Uglovaya',
#        'StoronySveta', 'Vidovaya', 'VidVoDvor', 'Cost', 'Area',
#        'PloshadVnutrenaya', 'RoomsCount', 'KolichestvoStoron', 'Podezd',
#        'Class', 'City', 'MaterialSten', 'Status', 'AgreementDate', 'SalePrice',
#        'Summa', 'ProcentVznosa', 'Aktsiya', 'AktsiyaGUID', 'DateOfSalesStart',
#        'FirstPrice', 'PloshadVnutrenayaPoTP', 'PloshadBalkonaPoTP',
#        'ZhilayaPloshadPoTP'],
#       dtype='object')

# %%
df['Uglovaya'] = df['Uglovaya'].astype('int')
df['Vidovaya'] = df['Vidovaya'].astype('int')
df['VidVoDvor'] = df['VidVoDvor'].astype('int')

# %% [markdown]
# **<h1>Missing data**

# %%
#Top20 columns with null values by ascending order

total = df.isnull().sum().sort_values(ascending=False)
percent = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data.head(20)
# Out:
#                       Total   Percent
# AktsiyaGUID         2970596  0.997365
# Aktsiya             2970596  0.997365
# AgreementDate       2966609  0.996027
# StoronySveta        2338298  0.785074
# MaterialSten           4746  0.001593
# KolichestvoStoron      3401  0.001142
# City                    132  0.000044
# DateOfSalesStart         37  0.000012
# Vidovaya                  0  0.000000
# Uglovaya                  0  0.000000
# Etazh                     0  0.000000
# DataVygruzki              0  0.000000
# Price                     0  0.000000
# Cost                      0  0.000000
# PomeshcheniyeGUID         0  0.000000
# Pomeshcheniye             0  0.000000
# ObjectGUID                0  0.000000
# ObjectName                0  0.000000
# VidVoDvor                 0  0.000000
# ZhilayaPloshadPoTP        0  0.000000

# %%
df['StoronySveta'].value_counts()
# Out:
# В     200305
# С     192263
# Ю     133910
# З     106542
# ЮЗ      4405
# ЮВ      1507
# СЗ       883
# СВ       330
# Name: StoronySveta, dtype: int64

# %% [markdown]
# **<h1>Status что с ним делать?**

# %%
df['Status'].value_counts()
# Out:
# Свободно    2869629
# Резерв        54227
# Бронь         42753
# Продано       11834
# Name: Status, dtype: int64

# %%
df['City'].value_counts()
# Out:
# Астана     2444676
# Алматы      506131
# Атырау       25527
# Бурабай       1977
# Name: City, dtype: int64

# %%
df['ObjectName'].nunique()
# Out:
# 203

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#price correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Price')['Price'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %% [markdown]
# **<h1>Without 'Svobodno'**

# %%
data = df[df['Status'] != 'Свободно']

# %%
data.shape
# Out:
# (108814, 33)

# %%
data['City'].value_counts()
# Out:
# Астана     72020
# Алматы     34684
# Атырау      2087
# Бурабай       23
# Name: City, dtype: int64

# %%
data.head()
# Out:
#           Data ObjectName  ... PloshadBalkonaPoTP ZhilayaPloshadPoTP
# 76  2019-01-26  Арнау - 8  ...                0.0                0.0
# 77  2019-01-26  Арнау - 8  ...                0.0                0.0
# 78  2019-01-26  Арнау - 8  ...                0.0                0.0
# 79  2019-01-26  Арнау - 8  ...                0.0                0.0
# 80  2019-01-26  Арнау - 8  ...                0.0                0.0
#
# [5 rows x 33 columns]

# %%
#Top20 columns with null values by ascending order

total = data.isnull().sum().sort_values(ascending=False)
percent = (data.isnull().sum()/data.isnull().count()).sort_values(ascending=False)
missing_data2 = pd.concat([total, percent], axis=1, keys=['Total', 'Percent'])
missing_data2.head(20)
# Out:
#                      Total   Percent
# AktsiyaGUID         100967  0.927886
# Aktsiya             100967  0.927886
# AgreementDate        96980  0.891246
# StoronySveta         90339  0.830215
# MaterialSten            50  0.000459
# KolichestvoStoron       23  0.000211
# DateOfSalesStart        23  0.000211
# VidVoDvor                0  0.000000
# Vidovaya                 0  0.000000
# Uglovaya                 0  0.000000
# Etazh                    0  0.000000
# DataVygruzki             0  0.000000
# Price                    0  0.000000
# Area                     0  0.000000
# PomeshcheniyeGUID        0  0.000000
# Pomeshcheniye            0  0.000000
# ObjectGUID               0  0.000000
# ObjectName               0  0.000000
# Cost                     0  0.000000
# ZhilayaPloshadPoTP       0  0.000000

# %%
corrmat = df.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat, vmax=.8, square=True);

# %%
#price correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Price')['Price'].index
cm = np.corrcoef(df[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()

# %%
data.columns
# Out:
# Index(['Data', 'ObjectName', 'ObjectGUID', 'Pomeshcheniye',
#        'PomeshcheniyeGUID', 'DataVygruzki', 'Price', 'Etazh', 'Uglovaya',
#        'StoronySveta', 'Vidovaya', 'VidVoDvor', 'Cost', 'Area',
#        'PloshadVnutrenaya', 'RoomsCount', 'KolichestvoStoron', 'Podezd',
#        'Class', 'City', 'MaterialSten', 'Status', 'AgreementDate', 'SalePrice',
#        'Summa', 'ProcentVznosa', 'Aktsiya', 'AktsiyaGUID', 'DateOfSalesStart',
#        'FirstPrice', 'PloshadVnutrenayaPoTP', 'PloshadBalkonaPoTP',
#        'ZhilayaPloshadPoTP'],
#       dtype='object')

# %%
data.drop(['SalePrice','PloshadVnutrenaya','Summa','ProcentVznosa', 'PloshadVnutrenayaPoTP', 'PloshadBalkonaPoTP', 'ZhilayaPloshadPoTP', 'StoronySveta', 'AgreementDate', 'Aktsiya', 'AktsiyaGUID'],
         axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data.drop('Status',axis = 1, inplace = True)
# Out:
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)

# %%
data.columns
# Out:
# Index(['Data', 'ObjectName', 'ObjectGUID', 'Pomeshcheniye',
#        'PomeshcheniyeGUID', 'DataVygruzki', 'Price', 'Etazh', 'Uglovaya',
#        'Vidovaya', 'VidVoDvor', 'Cost', 'Area', 'RoomsCount',
#        'KolichestvoStoron', 'Podezd', 'Class', 'City', 'MaterialSten',
#        'Status', 'DateOfSalesStart', 'FirstPrice'],
#       dtype='object')

# %%
data.shape
# Out:
# (108814, 22)

# %%
data.head()
# Out:
#           Data ObjectName  ... DateOfSalesStart FirstPrice
# 76  2019-01-26  Арнау - 8  ...       2018-11-28   309000.0
# 77  2019-01-26  Арнау - 8  ...       2018-11-28   306000.0
# 78  2019-01-26  Арнау - 8  ...       2018-11-28   317000.0
# 79  2019-01-26  Арнау - 8  ...       2018-11-28   312000.0
# 80  2019-01-26  Арнау - 8  ...       2018-11-28   323000.0
#
# [5 rows x 21 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 108814 entries, 76 to 2978442
# Data columns (total 21 columns):
# Data                 108814 non-null object
# ObjectName           108814 non-null object
# ObjectGUID           108814 non-null object
# Pomeshcheniye        108814 non-null object
# PomeshcheniyeGUID    108814 non-null object
# DataVygruzki         108814 non-null object
# Price                108814 non-null float64
# Etazh                108814 non-null int64
# Uglovaya             108814 non-null int64
# Vidovaya             108814 non-null int64
# VidVoDvor            108814 non-null int64
# Cost                 108814 non-null float64
# Area                 108814 non-null float64
# RoomsCount           108814 non-null int64
# KolichestvoStoron    108791 non-null float64
# Podezd               108814 non-null int64
# Class                108814 non-null int64
# City                 108814 non-null object
# MaterialSten         108764 non-null object
# DateOfSalesStart     108791 non-null object
# FirstPrice           108814 non-null float64
# dtypes: float64(5), int64(7), object(9)
# memory usage: 18.3+ MB

# %% [markdown]
# **<h2>Object to int**

# %%
data['KolichestvoStoron'].value_counts()
# Out:
# 2.0    64399
# 1.0    44392
# Name: KolichestvoStoron, dtype: int64

# %%
data['KolichestvoStoron'] = data['KolichestvoStoron'].map({'Односторонняя':1, 'Двухсторонняя':2})
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['Class'].value_counts()
# Out:
# Комфорт     50006
# Бизнес      32712
# Стандарт    23274
# Deluxe       2475
# Премиум       347
# Name: Class, dtype: int64

# %%
data['Class'] = data['Class'].map({'Стандарт':1, 'Комфорт':2, 'Бизнес':3, 'Deluxe':4, 'Премиум':5})
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data['MaterialSten'].value_counts()
# Out:
# Газоблок                                                                                                                                                70502
# Кирпич силикатный                                                                                                                                        7966
# Монолитный железобетон                                                                                                                                   6276
# Панель                                                                                                                                                   5441
# Вентилируемый фасад утеплитель каркас монолитный железобетонный стены из ячеистых блоков                                                                 4980
# Блоки из ячеистого бетона толщ. 250мм.                                                                                                                   2484
# Газоблок/железобетон                                                                                                                                     2018
# Кирпич керамический                                                                                                                                      2017
# 1-24 этажи блоки из газоблока толщ. 250мм.                                                                                                               1456
# Газоблок толщиной 300 мм с устройством утеплителя                                                                                                        1267
# 1-2 этажи кирпич с устройством утеплителя 3-14 этажи блоки из ячеистого бетона толщ. 250мм.                                                               623
# Керамический блок толщина стен 250 мм утепление 100-150 мм.                                                                                               591
# 2-24 этажи блоки из газоблока толщ. 250мм.                                                                                                                573
# Навесные стеновые панели                                                                                                                                  509
# Вентилируемый фасад утеплитель каркас монолитный железобетонный стены из ячеистых блоков газоблок                                                         479
# Газоблок/ железобетон                                                                                                                                     438
# Фасад комбинированный - Газоблок облицовка фасада фиброцементные панели витражи                                                                           235
# Газобетонный блок толщиной 250 мм с утеплением из минплиты                                                                                                164
# Вентилируемый фасад утеплитель каркас монолитный железобетонный газоблок                                                                                  134
# 1-2 этажи кирпич с устройством утеплителя 3-14 этажи блоки из ячеистого бетона толщ. 250мм.                                                               113
# ячеистый бетон с устройством утеплителя толщ. 250мм на балконах и лоджиях 200мм                                                                           113
# Из газобетонных блоков толщ. 250 мм                                                                                                                        92
# газоблок                                                                                                                                                   88
# 1 этажи кирпич с устройством утеплителя 2-14 этажи блоки из ячеистого бетона толщ. 250мм.                                                                  72
# газобетонные блоки из ячеистых бетонов армированные стеновые мелкие с утеплителем                                                                          29
# блоки из ячеистого бетона толщ. 250мм.                                                                                                                     26
# Каркас монолитный железобетонный                                                                                                                           21
# Газоблок толщ 250мм                                                                                                                                        15
# силикатный кирпич армированый толщиной 510 мм                                                                                                              11
# керамический кирпич армированый толщиной 510 мм                                                                                                             7
# из газоблока                                                                                                                                                6
# кирпич                                                                                                                                                      4
# газобетонные блоки                                                                                                                                          4
# в 9-ти этажном здании из силикатного кирпича с армированием и с устройством утепления из мин плиты  в 12-ти этажном здании блоки из ячейстого бетона        2
# пенобетонные блоки из ячеистых бетонов армированные стеновые мелкие с утеплителем                                                                           2
# Газоблок/Железобетон                                                                                                                                        2
# из силикатного кирпича с армированием и с устройством утепления из мин плиты                                                                                1
# Монолитный железобетонный каркас заполнение теплоблоками                                                                                                    1
# Газобетонные блоки толщ 250мм. утеплением минераловатными плитами толщиной 150мм.                                                                           1
# керамический кирпич                                                                                                                                         1
# Name: MaterialSten, dtype: int64

# %%
corr = data.corr()
ax = sns.heatmap(
    corr, 
    vmin=0, vmax=1, center=0,
    cmap=sns.diverging_palette(20, 220, n=200),
    square=True
)
ax.set_xticklabels(
    ax.get_xticklabels(),
    rotation=45,
    horizontalalignment='right'
);

# %%
corrmat = data.corr()
f, ax = plt.subplots(figsize=(12, 9))
sns.heatmap(corrmat,vmin = 0, vmax=1, square=True);

# %%
#price correlation matrix
k = 10 #number of variables for heatmap
cols = corrmat.nlargest(k, 'Price')['Price'].index
cm = np.corrcoef(data[cols].values.T)
sns.set(font_scale=1.25)
hm = sns.heatmap(cm, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 9}, yticklabels=cols.values, xticklabels=cols.values)
plt.show()
